# %% [markdown]
# # Local

# %%
root = ""

# %% [markdown]
# # Connect To Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
root = "drive/MyDrive/CMPLabData/Lexicon/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import csv
import random
import pickle
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from tqdm import tqdm
# from tensorflow.keras.utils import plot_model

# %% [markdown]
# # Import Words and Nonwords Data

# %%
words = []
frq = []
sum_frq = 0
with open(root + "Datasets/Items.csv", 'r') as file:
    reader = csv.reader(file)
    for idx, row in enumerate(reader):
        if idx ==0: 
            continue
        words.append([row[0], int(row[2].replace(',',''))])
        frq.append(int(row[2].replace(',','')))
        sum_frq += int(row[2].replace(',',''))
        
words.sort(key = lambda x: x[1], reverse=True)

all_words = [word[0] for word in words]
hf_words = all_words[:int(len(words)/2)]
lf_words = all_words[int(len(words)/2):]
# Another metric for defining hf an lf is good to be tested (something other than half of the words are hf
# and other half is lf)

# %%
def categorise_by_log_freq(row, freq_rate=6):
    if row['label'] == 0:
        return 'NW'
    elif row['label'] == 1 and row['log_freq'] > freq_rate:
        return 'HF'
    elif row['label'] == 1 and (row['log_freq'] >= 0 and row['log_freq'] <=freq_rate):
        return 'LF'

# %%
with open(root+'Datasets/words.pkl', 'rb') as f:
  words = pickle.load(f)

with open(root+'Datasets/nonwords.pkl', 'rb') as f:
  nonwords = pickle.load(f)

# %%
for w in words:
    w.insert(3, [1, 0])
    w.insert(4, 1)

for nw in nonwords:
    nw.insert(1, 0)
    nw.insert(3, [0, 1])
    nw.insert(4, 0)

# %%
word_df = pd.DataFrame(words + nonwords,
               columns =['string', 'freq', 'represention', 'code', 'label'])
word_df['freq'] = word_df['freq'].astype('int')
word_df['log_freq'] = np.round(np.log(word_df['freq']+1))

# First HF, LF, NW categorization
category = []
for index, row in tqdm(word_df.iterrows()):
    if row['label']==0:
        category.append("NW")
    elif row[0] in hf_words:
        category.append("HF")
    elif row[0] in lf_words:
        category.append("LF")
word_df['category'] = category

# Alternative HF, LF, NW categorization 
word_df['category_a'] = word_df.apply(lambda row: categorise_by_log_freq(row, 8), axis=1)

word_df
# Out:
# 80822it [00:47, 1698.68it/s]
#                    string      freq  \
# 0                       a  10610626
# 1                     aah       222
# 2                   Aaron     10806
# 3                   aback       387
# 4                  abacus       513
# ...                   ...       ...
# 80817    declassificarion         0
# 80818  antifundamentadast         0
# 80819    transcontanental         0
# 80820                  iv         0
# 80821    tharacterization         0
#
#                                             represention    code  label  \
# 0      [0.11558813, 0.30192456, -0.114647746, 0.01000...  [1, 0]      1
# 1      [0.08188029, -0.12485198, -0.3285692, 0.374986...  [1, 0]      1
# 2      [0.12105307, 0.058084395, -0.013443807, 0.1779...  [1, 0]      1
# 3      [-0.11328265, -0.23398337, -0.58877015, 0.2669...  [1, 0]      1
# 4      [0.19533455, 0.10326072, -0.19377021, 0.234316...  [1, 0]      1
# ...                                                  ...     ...    ...
# 80817  [-0.1627126, -0.21505767, 0.2029604, 0.0559478...  [0, 1]      0
# 80818  [-0.09716947, -0.056558426, -0.18841882, -0.04...  [0, 1]      0
# 80819  [0.22957236, -0.21539333, -0.027639901, 0.1270...  [0, 1]      0
# 80820  [-0.42683536, -0.50000775, -0.16295096, -0.305...  [0, 1]      0
# 80821  [-0.1959866, -0.14983886, -0.6857146, 0.437132...  [0, 1]      0
#
#        log_freq category category_a
# 0          16.0       HF         HF
# 1           5.0       LF         LF
# 2           9.0       HF         HF
# 3           6.0       LF         LF
# 4           6.0       HF         LF
# ...         ...      ...        ...
# 80817       0.0       NW         NW
# 80818       0.0       NW         NW
# 80819       0.0       NW         NW
# 80820       0.0       NW         NW
# 80821       0.0       NW         NW
#
# [80822 rows x 8 columns]

# %%
HF_LF_df = word_df.loc[word_df['log_freq']!=0]
duplicates = []
for index, row in tqdm(HF_LF_df.iterrows()):
  if(row['category_a']=='HF'):
    for i in range(int(row['log_freq'])):
        duplicates.append(row)
  # else:
  #   if row[1] > 1:
  #     duplicates.append(row)
duplicates_df = pd.DataFrame(duplicates).reset_index(drop=True)
# Out:
# 39965it [00:02, 15567.44it/s]

# %%
duplicates_df
# Out:
#       string      freq                                       represention  \
# 0          a  10610626  [0.11558813, 0.30192456, -0.114647746, 0.01000...
# 1          a  10610626  [0.11558813, 0.30192456, -0.114647746, 0.01000...
# 2          a  10610626  [0.11558813, 0.30192456, -0.114647746, 0.01000...
# 3          a  10610626  [0.11558813, 0.30192456, -0.114647746, 0.01000...
# 4          a  10610626  [0.11558813, 0.30192456, -0.114647746, 0.01000...
# ...      ...       ...                                                ...
# 63116   zoom      4920  [-0.36649638, 0.68561196, 0.1494862, -0.219817...
# 63117   zoom      4920  [-0.36649638, 0.68561196, 0.1494862, -0.219817...
# 63118   zoom      4920  [-0.36649638, 0.68561196, 0.1494862, -0.219817...
# 63119   zoom      4920  [-0.36649638, 0.68561196, 0.1494862, -0.219817...
# 63120   zoom      4920  [-0.36649638, 0.68561196, 0.1494862, -0.219817...
#
#          code  label  log_freq category category_a
# 0      [1, 0]      1      16.0       HF         HF
# 1      [1, 0]      1      16.0       HF         HF
# 2      [1, 0]      1      16.0       HF         HF
# 3      [1, 0]      1      16.0       HF         HF
# 4      [1, 0]      1      16.0       HF         HF
# ...       ...    ...       ...      ...        ...
# 63116  [1, 0]      1       9.0       HF         HF
# 63117  [1, 0]      1       9.0       HF         HF
# 63118  [1, 0]      1       9.0       HF         HF
# 63119  [1, 0]      1       9.0       HF         HF
# 63120  [1, 0]      1       9.0       HF         HF
#
# [63121 rows x 8 columns]

# %% [markdown]
# ## Concat

# %%
# mode_space_df = pd.concat([word_df, duplicates_df]).sample(frac=1.0).reset_index(drop=True)
mode_space_df = word_df
mode_space_df
# Out:
#                    string      freq  \
# 0                       a  10610626
# 1                     aah       222
# 2                   Aaron     10806
# 3                   aback       387
# 4                  abacus       513
# ...                   ...       ...
# 80817    declassificarion         0
# 80818  antifundamentadast         0
# 80819    transcontanental         0
# 80820                  iv         0
# 80821    tharacterization         0
#
#                                             represention    code  label  \
# 0      [0.11558813, 0.30192456, -0.114647746, 0.01000...  [1, 0]      1
# 1      [0.08188029, -0.12485198, -0.3285692, 0.374986...  [1, 0]      1
# 2      [0.12105307, 0.058084395, -0.013443807, 0.1779...  [1, 0]      1
# 3      [-0.11328265, -0.23398337, -0.58877015, 0.2669...  [1, 0]      1
# 4      [0.19533455, 0.10326072, -0.19377021, 0.234316...  [1, 0]      1
# ...                                                  ...     ...    ...
# 80817  [-0.1627126, -0.21505767, 0.2029604, 0.0559478...  [0, 1]      0
# 80818  [-0.09716947, -0.056558426, -0.18841882, -0.04...  [0, 1]      0
# 80819  [0.22957236, -0.21539333, -0.027639901, 0.1270...  [0, 1]      0
# 80820  [-0.42683536, -0.50000775, -0.16295096, -0.305...  [0, 1]      0
# 80821  [-0.1959866, -0.14983886, -0.6857146, 0.437132...  [0, 1]      0
#
#        log_freq category category_a
# 0          16.0       HF         HF
# 1           5.0       LF         LF
# 2           9.0       HF         HF
# 3           6.0       LF         LF
# 4           6.0       HF         LF
# ...         ...      ...        ...
# 80817       0.0       NW         NW
# 80818       0.0       NW         NW
# 80819       0.0       NW         NW
# 80820       0.0       NW         NW
# 80821       0.0       NW         NW
#
# [80822 rows x 8 columns]

# %%
train_dataframe = mode_space_df.iloc[:int(len(mode_space_df)*0.8), :] 
valid_dataframe = mode_space_df.iloc[int(len(mode_space_df)*0.8):, :]

# %% [markdown]
# # Nueral Network

# %%
# Sequential Model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Input(shape=(300,)))
model.add(layers.Dense(300, activation="relu", name="dense1"))
model.add(layers.Dense(10, activation="relu", name="dense4"))
model.add(layers.Dense(2, activation='softmax', name='clf'))

opt = tf.keras.optimizers.SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=opt,
              loss=tf.keras.losses.categorical_crossentropy,
              metrics=['accuracy'])

model.summary()
# plot_model(model, to_file='model.png', show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense1 (Dense)              (None, 300)               90300
#
#  dense4 (Dense)              (None, 10)                3010
#
#  clf (Dense)                 (None, 2)                 22
#
# =================================================================
# Total params: 93,332
# Trainable params: 93,332
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
history = model.fit(
    x=np.array(list(train_dataframe['represention'])),
    y=np.array(list(train_dataframe['code'])),
    validation_data=(np.array(list(valid_dataframe['represention'])), np.array(list(valid_dataframe['code']))),
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True
        )
    ],
    epochs=10)
# Out:
# Epoch 1/10
# 2021/2021 [==============================] - 7s 3ms/step - loss: 0.4570 - accuracy: 0.7880 - val_loss: 0.5788 - val_accuracy: 0.7218
# Epoch 2/10
# 2021/2021 [==============================] - 9s 5ms/step - loss: 0.3487 - accuracy: 0.8579 - val_loss: 0.4290 - val_accuracy: 0.8179
# Epoch 3/10
# 2021/2021 [==============================] - 7s 4ms/step - loss: 0.3174 - accuracy: 0.8724 - val_loss: 0.5429 - val_accuracy: 0.7730
# Epoch 4/10
# 2021/2021 [==============================] - 7s 3ms/step - loss: 0.2948 - accuracy: 0.8834 - val_loss: 0.4216 - val_accuracy: 0.8308
# Epoch 5/10
# 2021/2021 [==============================] - 6s 3ms/step - loss: 0.2763 - accuracy: 0.8923 - val_loss: 0.4402 - val_accuracy: 0.8202
# Epoch 6/10
# 2021/2021 [==============================] - 6s 3ms/step - loss: 0.2611 - accuracy: 0.8987 - val_loss: 0.3780 - val_accuracy: 0.8478
# Epoch 7/10
# 2021/2021 [==============================] - 6s 3ms/step - loss: 0.2476 - accuracy: 0.9042 - val_loss: 0.4100 - val_accuracy: 0.8342
# Epoch 8/10
# 2021/2021 [==============================] - 6s 3ms/step - loss: 0.2356 - accuracy: 0.9090 - val_loss: 0.4016 - val_accuracy: 0.8376
# Epoch 9/10
# 2021/2021 [==============================] - 7s 3ms/step - loss: 0.2242 - accuracy: 0.9142 - val_loss: 0.4179 - val_accuracy: 0.8322
# Epoch 10/10
# 2021/2021 [==============================] - 6s 3ms/step - loss: 0.2143 - accuracy: 0.9180 - val_loss: 0.3354 - val_accuracy: 0.8676

# %%
y_preds = model.predict(np.array(list(train_dataframe['represention'])))

# %%
y_preds.shape
# Out:
# (64657, 2)

# %%
y_preds
# Out:
# array([[0.9062808 , 0.09371914],
#        [0.6021876 , 0.3978125 ],
#        [0.8470599 , 0.1529401 ],
#        ...,
#        [0.01744834, 0.9825516 ],
#        [0.00530944, 0.9946905 ],
#        [0.01771074, 0.98228925]], dtype=float32)

# %%
print(classification_report(np.argmax(np.array(list(train_dataframe['code'])), axis=1), np.argmax(y_preds, axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94     40481
#            1       0.89      0.91      0.90     24176
#
#     accuracy                           0.92     64657
#    macro avg       0.92      0.92      0.92     64657
# weighted avg       0.92      0.92      0.92     64657

# %%
model.save(root+"check_points/NN_model")
# Out:
# INFO:tensorflow:Assets written to: drive/MyDrive/CMPLabData/Lexicon/check_points/NN_model/assets

# %% [markdown]
# # Check Probabilities

# %%
full_dataset_predictions = model.predict(np.array(list(word_df['represention'])))

# %%
full_dataset_predictions.shape
# Out:
# (80822, 2)

# %%
word_df['word_prob']=full_dataset_predictions[:,0]
word_df['nword_prob']=full_dataset_predictions[:,1]
word_df['logit']=np.log(word_df['word_prob']/word_df['nword_prob'])

# %%
word_df
# Out:
#                    string      freq  \
# 0                       a  10610626
# 1                     aah       222
# 2                   Aaron     10806
# 3                   aback       387
# 4                  abacus       513
# ...                   ...       ...
# 80817    declassificarion         0
# 80818  antifundamentadast         0
# 80819    transcontanental         0
# 80820                  iv         0
# 80821    tharacterization         0
#
#                                             represention    code  label  \
# 0      [0.11558813, 0.30192456, -0.114647746, 0.01000...  [1, 0]      1
# 1      [0.08188029, -0.12485198, -0.3285692, 0.374986...  [1, 0]      1
# 2      [0.12105307, 0.058084395, -0.013443807, 0.1779...  [1, 0]      1
# 3      [-0.11328265, -0.23398337, -0.58877015, 0.2669...  [1, 0]      1
# 4      [0.19533455, 0.10326072, -0.19377021, 0.234316...  [1, 0]      1
# ...                                                  ...     ...    ...
# 80817  [-0.1627126, -0.21505767, 0.2029604, 0.0559478...  [0, 1]      0
# 80818  [-0.09716947, -0.056558426, -0.18841882, -0.04...  [0, 1]      0
# 80819  [0.22957236, -0.21539333, -0.027639901, 0.1270...  [0, 1]      0
# 80820  [-0.42683536, -0.50000775, -0.16295096, -0.305...  [0, 1]      0
# 80821  [-0.1959866, -0.14983886, -0.6857146, 0.437132...  [0, 1]      0
#
#        log_freq category category_a  word_prob  nword_prob     logit
# 0          16.0       HF         HF   0.906281    0.093719  2.269047
# 1           5.0       LF         LF   0.602188    0.397812  0.414588
# 2           9.0       HF         HF   0.847060    0.152940  1.711725
# 3           6.0       LF         LF   0.928595    0.071405  2.565301
# 4           6.0       HF         LF   0.967652    0.032348  3.398307
# ...         ...      ...        ...        ...         ...       ...
# 80817       0.0       NW         NW   0.207975    0.792025 -1.337176
# 80818       0.0       NW         NW   0.008859    0.991141 -4.717467
# 80819       0.0       NW         NW   0.032687    0.967313 -3.387558
# 80820       0.0       NW         NW   0.847766    0.152234  1.717187
# 80821       0.0       NW         NW   0.077157    0.922843 -2.481617
#
# [80822 rows x 11 columns]

# %%
word_df.groupby(['category']).agg({'word_prob': ['mean', 'std', 'count'], 'nword_prob': ['mean', 'std', 'count'],
                                  'logit': ['mean', 'std', 'count']})
# Out:
#          word_prob                  nword_prob                      logit  \
#               mean       std  count       mean       std  count      mean
# category
# HF        0.907862  0.164081  20240   0.092138  0.164081  20240  3.461720
# LF        0.840264  0.218612  20241   0.159736  0.218612  20241  2.633909
# NW        0.154113  0.233773  40341   0.845887  0.233773  40341 -2.912167
#
#
#                std  count
# category
# HF        1.892805  20240
# LF        2.011414  20241
# NW        2.297908  40341

# %%
word_df.groupby(['category_a']).agg({'word_prob': ['mean', 'std', 'count'], 'nword_prob': ['mean', 'std', 'count'],
                                  'logit': ['mean', 'std', 'count']})
# Out:
#            word_prob                  nword_prob                      logit  \
#                 mean       std  count       mean       std  count      mean
# category_a
# HF          0.915882  0.153521   6423   0.084118  0.153521   6423  3.573848
# LF          0.866175  0.202294  34058   0.133825  0.202294  34058  2.948598
# NW          0.154113  0.233773  40341   0.845887  0.233773  40341 -2.912167
#
#
#                  std  count
# category_a
# HF          1.885983   6423
# LF          2.001094  34058
# NW          2.297908  40341

# %%
word_df_to_save = word_df.drop(['represention', 'code','category'], axis=1)
word_df_to_save = word_df_to_save.rename(columns={"category_a": "category", "B": "c"})

# %%
word_df_to_save.to_csv(root+"Datasets/full_dataset_prob_a.csv", header=0, index=False)

# %%
word_df_to_save
# Out:
#                    string      freq  label  log_freq category  word_prob  \
# 0                       a  10610626      1      16.0       HF   0.906281
# 1                     aah       222      1       5.0       LF   0.602188
# 2                   Aaron     10806      1       9.0       HF   0.847060
# 3                   aback       387      1       6.0       LF   0.928595
# 4                  abacus       513      1       6.0       LF   0.967652
# ...                   ...       ...    ...       ...      ...        ...
# 80817    declassificarion         0      0       0.0       NW   0.207975
# 80818  antifundamentadast         0      0       0.0       NW   0.008859
# 80819    transcontanental         0      0       0.0       NW   0.032687
# 80820                  iv         0      0       0.0       NW   0.847766
# 80821    tharacterization         0      0       0.0       NW   0.077157
#
#        nword_prob     logit
# 0        0.093719  2.269047
# 1        0.397812  0.414588
# 2        0.152940  1.711725
# 3        0.071405  2.565301
# 4        0.032348  3.398307
# ...           ...       ...
# 80817    0.792025 -1.337176
# 80818    0.991141 -4.717467
# 80819    0.967313 -3.387558
# 80820    0.152234  1.717187
# 80821    0.922843 -2.481617
#
# [80822 rows x 8 columns]
